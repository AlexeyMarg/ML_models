# %% [markdown]
# # Text data cleaning

# %%
import nltk
import requests
from nltk.tokenize import word_tokenize
import re
#nltk.download()

# %%
data_url = "https://www.gutenberg.org/ebooks/4367.txt.utf-8"
file_name = "data.txt"

# %%
response = requests.get(data_url)
with open(f"{file_name}", "wb") as f:
    f.write(response.content)

# %% [markdown]
# ## Manual tokenization

# %% [markdown]
# ### Split to words

# %%
with open(f"{file_name}", 'r', encoding='utf-8') as f:
    data = f.read()
words = data.split()
words[:10]
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'Personal',
#  'Memoirs',
#  'of',
#  'U.',
#  'S.']

# %%
words = re.split(r'\W+', data)
print(words[:100])
# Out:
# ['', 'The', 'Project', 'Gutenberg', 'eBook', 'of', 'Personal', 'Memoirs', 'of', 'U', 'S', 'Grant', 'Complete', 'This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', 'You', 'may', 'copy', 'it', 'give', 'it', 'away', 'or', 're', 'use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at', 'www', 'gutenberg', 'org', 'If', 'you', 'are', 'not', 'located', 'in', 'the', 'United', 'States', 'you', 'will', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'eBook', 'Title', 'Personal']

# %% [markdown]
# ### Remove punctuation

# %%
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in words]
print(stripped[:10])
# Out:
# ['', 'The', 'Project', 'Gutenberg', 'eBook', 'of', 'Personal', 'Memoirs', 'of', 'U']

# %% [markdown]
# ### Normalizing

# %%
words = [word.lower() for word in words]
print(words[:10])
# Out:
# ['', 'the', 'project', 'gutenberg', 'ebook', 'of', 'personal', 'memoirs', 'of', 'u']

# %% [markdown]
# ## NLTK tokenization

# %% [markdown]
# ### Split to sentences

# %%
with open(f"{file_name}", "r", encoding='utf-8') as f:
    data = f.read()
sentences = nltk.sent_tokenize(data)
sentences[1]
# Out:
# 'You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this eBook or online\nat www.gutenberg.org.'

# %% [markdown]
# ### Split into words

# %%
with open(f"{file_name}", "r", encoding='utf-8') as f:
    data = f.read()
tokens = word_tokenize(data)
print(tokens[:10])
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'eBook', 'of', 'Personal', 'Memoirs', 'of', 'U.', 'S.']

# %% [markdown]
# ### Filter Out Punctuation

# %%
words = [word for word in tokens if word.isalpha()]
print(words[:10])
# Out:
# ['Project', 'Gutenberg', 'eBook', 'of', 'Personal', 'Memoirs', 'of', 'Grant', 'Complete', 'This']

# %% [markdown]
# ### Filter out Stop Words

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
print(stop_words)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %% [markdown]
# ### Pipeline

# %%
with open(f"{file_name}", "r", encoding='utf-8') as f:
    data = f.read()
tokens = word_tokenize(data)
tokens = [w.lower() for w in tokens]

table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]

words = [word for word in stripped if word.isalpha()]

stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]

print(words[:10])
# Out:
# ['project', 'gutenberg', 'ebook', 'personal', 'memoirs', 'u', 'grant', 'complete', 'ebook', 'use']

# %%
with open(f"data_tokens.txt", "w", encoding='utf-8') as f:    
    for word in words:
        f.write(word+' ')
