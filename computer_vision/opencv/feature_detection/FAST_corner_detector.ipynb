# %% [markdown]
# # FAST Algorithm for Corner Detection

# %% [markdown]
# FAST (Features from Accelerated Segment Test) algorithm was proposed  for high-speed corner detection

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
img_path = os.path.join('..', '..', 'pics', 'pic.jpg')
img = cv.imread(img_path)
gray =cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
# Initiate FAST object with default values
fast = cv.FastFeatureDetector_create()

# %%
kp = fast.detect(img,None)
img2 = cv.drawKeypoints(img, kp, None, color=(255,0,0))

# %%
# Print all default params
print( "Threshold: {}".format(fast.getThreshold()) )
print( "nonmaxSuppression:{}".format(fast.getNonmaxSuppression()) )
print( "neighborhood: {}".format(fast.getType()) )
print( "Total Keypoints with nonmaxSuppression: {}".format(len(kp)) )
# Out:
# Threshold: 10
# nonmaxSuppression:True
# neighborhood: 2
# Total Keypoints with nonmaxSuppression: 1314

# %%
plt.imshow(img2)

# %%
fast.setNonmaxSuppression(100)
fast.setThreshold(100)
kp = fast.detect(img, None)

kp = fast.detect(img,None)
img2 = cv.drawKeypoints(img, kp, None, color=(255,0,0))
plt.imshow(img2)
