# %% [markdown]
# # SIFT keypoint detector

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
img_path = os.path.join('..', '..', 'pics', 'pic.jpg')
img = cv.imread(img_path)
gray =cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
sift = cv.SIFT_create()
kp = sift.detect(gray, None)
 
img=cv.drawKeypoints(gray, kp, img)
plt.imshow(img)

# %%
img=cv.drawKeypoints(gray,kp,img,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.imshow(img)

# %% [markdown]
# Descriptors calculation

# %%
desc = sift.detectAndCompute(gray,None)
desc
# Out:
# ((< cv2.KeyPoint 0000026D2EE3A700>,
#   < cv2.KeyPoint 0000026D2F344DE0>,
#   < cv2.KeyPoint 0000026D2F344F30>,
#   < cv2.KeyPoint 0000026D2F344F60>,
#   < cv2.KeyPoint 0000026D2F344060>,
#   < cv2.KeyPoint 0000026D2F344EA0>,
#   < cv2.KeyPoint 0000026D2F344420>,
#   < cv2.KeyPoint 0000026D2F3443C0>,
#   < cv2.KeyPoint 0000026D2F344330>,
#   < cv2.KeyPoint 0000026D2F3447B0>,
#   < cv2.KeyPoint 0000026D2F344B70>,
#   < cv2.KeyPoint 0000026D2F344A20>,
#   < cv2.KeyPoint 0000026D2F344E10>,
#   < cv2.KeyPoint 0000026D2F344E70>,
#   < cv2.KeyPoint 0000026D2F344BD0>,
#   < cv2.KeyPoint 0000026D2F344750>,
#   < cv2.KeyPoint 0000026D2F344B10>,
#   < cv2.KeyPoint 0000026D2F3444B0>,
#   < cv2.KeyPoint 0000026D2F344990>,
#   < cv2.KeyPoint 0000026D2F3449F0>,
#   < cv2.KeyPoint 0000026D2F344180>,
#   < cv2.KeyPoint 0000026D2F344150>,
#   < cv2.KeyPoint 0000026D2F344240>,
#   < cv2.KeyPoint 0000026D2F3441E0>,
#   < cv2.KeyPoint 0000026D2F3441B0>,
#   < cv2.KeyPoint 0000026D2F344210>,
#   < cv2.KeyPoint 0000026D2F344480>,
#   < cv2.KeyPoint 0000026D2F344450>,
#   < cv2.KeyPoint 0000026D2F344510>,
#   < cv2.KeyPoint 0000026D2F344720>,
#   < cv2.KeyPoint 0000026D2F3446F0>,
#   < cv2.KeyPoint 0000026D2F3445A0>,
#   < cv2.KeyPoint 0000026D2F344570>,
#   < cv2.KeyPoint 0000026D2F344660>,
#   < cv2.KeyPoint 0000026D2F344600>,
#   < cv2.KeyPoint 0000026D2F3445D0>,
#   < cv2.KeyPoint 0000026D2F344630>,
#   < cv2.KeyPoint 0000026D2F3446C0>,
#   < cv2.KeyPoint 0000026D2F344690>,
#   < cv2.KeyPoint 0000026D2F344930>,
#   < cv2.KeyPoint 0000026D2F344120>,
#   < cv2.KeyPoint 0000026D2F3440F0>,
#   < cv2.KeyPoint 0000026D2F3440C0>,
#   < cv2.KeyPoint 0000026D2F344090>,
#   < cv2.KeyPoint 0000026D2F344C30>,
#   < cv2.KeyPoint 0000026D2F344C60>,
#   < cv2.KeyPoint 0000026D2F344C90>,
#   < cv2.KeyPoint 0000026D2F344CC0>,
#   < cv2.KeyPoint 0000026D2F344900>,
#   < cv2.KeyPoint 0000026D2F344360>,
#   < cv2.KeyPoint 0000026D2F344CF0>,
#   < cv2.KeyPoint 0000026D2F344D20>,
#   < cv2.KeyPoint 0000026D2F344F00>,
#   < cv2.KeyPoint 0000026D2F344300>,
#   < cv2.KeyPoint 0000026D2F3442D0>,
#   < cv2.KeyPoint 0000026D2F344ED0>,
#   < cv2.KeyPoint 0000026D2F3448D0>,
#   < cv2.KeyPoint 0000026D2F344840>,
#   < cv2.KeyPoint 0000026D2F344870>,
#   < cv2.KeyPoint 0000026D2F32B4E0>,
#   < cv2.KeyPoint 0000026D2F32BBD0>,
#   < cv2.KeyPoint 0000026D2F32BA20>,
#   < cv2.KeyPoint 0000026D2F32BA50>,
#   < cv2.KeyPoint 0000026D2F32BC30>,
#   < cv2.KeyPoint 0000026D2F32BC60>,
#   < cv2.KeyPoint 0000026D2F32BC90>,
#   < cv2.KeyPoint 0000026D2F32B660>,
#   < cv2.KeyPoint 0000026D2F32B690>,
#   < cv2.KeyPoint 0000026D2F32BBA0>,
#   < cv2.KeyPoint 0000026D2F32B960>,
#   < cv2.KeyPoint 0000026D2F32B510>,
#   < cv2.KeyPoint 0000026D2F32B720>,
#   < cv2.KeyPoint 0000026D2F32B990>,
#   < cv2.KeyPoint 0000026D2F32B9F0>,
#   < cv2.KeyPoint 0000026D2F32B9C0>,
#   < cv2.KeyPoint 0000026D2F32BFC0>,
#   < cv2.KeyPoint 0000026D2F32BC00>,
#   < cv2.KeyPoint 0000026D2F32BF90>,
#   < cv2.KeyPoint 0000026D2F32B4B0>,
#   < cv2.KeyPoint 0000026D2F32BF60>,
#   < cv2.KeyPoint 0000026D2F32BF30>,
#   < cv2.KeyPoint 0000026D2F32BF00>,
#   < cv2.KeyPoint 0000026D2F32BED0>,
#   < cv2.KeyPoint 0000026D2F32BEA0>,
#   < cv2.KeyPoint 0000026D2F32BE70>,
#   < cv2.KeyPoint 0000026D2F32BE40>,
#   < cv2.KeyPoint 0000026D2F32BE10>,
#   < cv2.KeyPoint 0000026D2F32BDE0>,
#   < cv2.KeyPoint 0000026D2F32BDB0>,
#   < cv2.KeyPoint 0000026D2F32BD80>,
#   < cv2.KeyPoint 0000026D2F32BD50>,
#   < cv2.KeyPoint 0000026D2F32BD20>,
#   < cv2.KeyPoint 0000026D2F32BCF0>,
#   < cv2.KeyPoint 0000026D2F32BCC0>,
#   < cv2.KeyPoint 0000026D2F32B930>,
#   < cv2.KeyPoint 0000026D2F32B900>,
#   < cv2.KeyPoint 0000026D2F32B8D0>,
#   < cv2.KeyPoint 0000026D2F32B8A0>,
#   < cv2.KeyPoint 0000026D2F32B870>,
#   < cv2.KeyPoint 0000026D2F32B840>,
#   < cv2.KeyPoint 0000026D2F32B810>,
#   < cv2.KeyPoint 0000026D2F32B7E0>,
#   < cv2.KeyPoint 0000026D2F32B7B0>,
#   < cv2.KeyPoint 0000026D2F32B780>,
#   < cv2.KeyPoint 0000026D2F32B630>,
#   < cv2.KeyPoint 0000026D2F32B600>,
#   < cv2.KeyPoint 0000026D2F32B5D0>,
#   < cv2.KeyPoint 0000026D2F32B5A0>,
#   < cv2.KeyPoint 0000026D2F32B570>,
#   < cv2.KeyPoint 0000026D2F32B540>,
#   < cv2.KeyPoint 0000026D2F32B3C0>,
#   < cv2.KeyPoint 0000026D2F32BB70>,
#   < cv2.KeyPoint 0000026D2F32BB40>,
#   < cv2.KeyPoint 0000026D2F32BB10>,
#   < cv2.KeyPoint 0000026D2F32BAE0>,
#   < cv2.KeyPoint 0000026D2F32BAB0>,
#   < cv2.KeyPoint 0000026D2F32BA80>,
#   < cv2.KeyPoint 0000026D2F32B750>,
#   < cv2.KeyPoint 0000026D2F32B6F0>,
#   < cv2.KeyPoint 0000026D2F32B6C0>,
#   < cv2.KeyPoint 0000026D2F15A0A0>,
#   < cv2.KeyPoint 0000026D2F15A250>,
#   < cv2.KeyPoint 0000026D2F15A010>,
#   < cv2.KeyPoint 0000026D2F15A4C0>,
#   < cv2.KeyPoint 0000026D2F15BC30>,
#   < cv2.KeyPoint 0000026D2F15A880>,
#   < cv2.KeyPoint 0000026D2F2F9230>,
#   < cv2.KeyPoint 0000026D2F2F9650>,
#   < cv2.KeyPoint 0000026D2F2F9500>,
#   < cv2.KeyPoint 0000026D2F2F95F0>,
#   < cv2.KeyPoint 0000026D2F2F8990>,
#   < cv2.KeyPoint 0000026D2F2F9410>,
#   < cv2.KeyPoint 0000026D2F2F8960>,
#   < cv2.KeyPoint 0000026D2F2F8150>,
#   < cv2.KeyPoint 0000026D2F2F84B0>,
#   < cv2.KeyPoint 0000026D2F2F89C0>,
#   < cv2.KeyPoint 0000026D2F2F8360>,
#   < cv2.KeyPoint 0000026D2F2F8C00>,
#   < cv2.KeyPoint 0000026D2F2F93E0>,
#   < cv2.KeyPoint 0000026D2F3A58C0>,
#   < cv2.KeyPoint 0000026D2F3A58F0>,
#   < cv2.KeyPoint 0000026D2F3A5920>,
#   < cv2.KeyPoint 0000026D2F3A5950>,
#   < cv2.KeyPoint 0000026D2F3A5980>,
#   < cv2.KeyPoint 0000026D2F3A59B0>,
#   < cv2.KeyPoint 0000026D2F3A71E0>,
#   < cv2.KeyPoint 0000026D2F3A7210>,
#   < cv2.KeyPoint 0000026D2F3A7240>,
#   < cv2.KeyPoint 0000026D2F3A71B0>,
#   < cv2.KeyPoint 0000026D2F3A7180>,
#   < cv2.KeyPoint 0000026D2F3A7150>,
#   < cv2.KeyPoint 0000026D2F3A7120>,
#   < cv2.KeyPoint 0000026D2F3A70F0>,
#   < cv2.KeyPoint 0000026D2F3A72A0>,
#   < cv2.KeyPoint 0000026D2F3A72D0>,
#   < cv2.KeyPoint 0000026D2F3A7300>,
#   < cv2.KeyPoint 0000026D2F3A7270>,
#   < cv2.KeyPoint 0000026D2F3A5590>,
#   < cv2.KeyPoint 0000026D2F3A5740>,
#   < cv2.KeyPoint 0000026D2F3A5710>,
#   < cv2.KeyPoint 0000026D2F3A56E0>,
#   < cv2.KeyPoint 0000026D2F3A5770>,
#   < cv2.KeyPoint 0000026D2F3A57A0>,
#   < cv2.KeyPoint 0000026D2F3A70C0>,
#   < cv2.KeyPoint 0000026D2F3A7090>,
#   < cv2.KeyPoint 0000026D2F3A7060>,
#   < cv2.KeyPoint 0000026D2F3A7030>,
#   < cv2.KeyPoint 0000026D2F3A7000>,
#   < cv2.KeyPoint 0000026D2F3A6FD0>,
#   < cv2.KeyPoint 0000026D2F3A6FA0>,
#   < cv2.KeyPoint 0000026D2F3A6F70>,
#   < cv2.KeyPoint 0000026D2F3A6F40>,
#   < cv2.KeyPoint 0000026D2F3A6F10>,
#   < cv2.KeyPoint 0000026D2F3A6EE0>,
#   < cv2.KeyPoint 0000026D2F3A6EB0>,
#   < cv2.KeyPoint 0000026D2F3A6E80>,
#   < cv2.KeyPoint 0000026D2F3A6E50>,
#   < cv2.KeyPoint 0000026D2F3A6E20>,
#   < cv2.KeyPoint 0000026D2F3A6DF0>,
#   < cv2.KeyPoint 0000026D2F3A6DC0>,
#   < cv2.KeyPoint 0000026D2F3A6D90>,
#   < cv2.KeyPoint 0000026D2F3A6D60>,
#   < cv2.KeyPoint 0000026D2F3A6D30>,
#   < cv2.KeyPoint 0000026D2F3A6D00>,
#   < cv2.KeyPoint 0000026D2F3A6CD0>,
#   < cv2.KeyPoint 0000026D2F3A6CA0>,
#   < cv2.KeyPoint 0000026D2F3A6C70>,
#   < cv2.KeyPoint 0000026D2F3A6C40>,
#   < cv2.KeyPoint 0000026D2F3A6C10>,
#   < cv2.KeyPoint 0000026D2F3A6BE0>,
#   < cv2.KeyPoint 0000026D2F3A6BB0>,
#   < cv2.KeyPoint 0000026D2F3A6B80>,
#   < cv2.KeyPoint 0000026D2F3A6B50>,
#   < cv2.KeyPoint 0000026D2F3A6B20>,
#   < cv2.KeyPoint 0000026D2F3A6AF0>,
#   < cv2.KeyPoint 0000026D2F3A6AC0>,
#   < cv2.KeyPoint 0000026D2F3A6A90>,
#   < cv2.KeyPoint 0000026D2F3A6A60>,
#   < cv2.KeyPoint 0000026D2F3A6A30>,
#   < cv2.KeyPoint 0000026D2F3A6A00>,
#   < cv2.KeyPoint 0000026D2F3A69D0>,
#   < cv2.KeyPoint 0000026D2F3A69A0>,
#   < cv2.KeyPoint 0000026D2F3A6970>,
#   < cv2.KeyPoint 0000026D2F3A6940>,
#   < cv2.KeyPoint 0000026D2F3A6910>,
#   < cv2.KeyPoint 0000026D2F3A68E0>,
#   < cv2.KeyPoint 0000026D2F3A68B0>,
#   < cv2.KeyPoint 0000026D2F3A6880>,
#   < cv2.KeyPoint 0000026D2F3A6850>,
#   < cv2.KeyPoint 0000026D2F3A6820>,
#   < cv2.KeyPoint 0000026D2F3A67F0>,
#   < cv2.KeyPoint 0000026D2F3A67C0>,
#   < cv2.KeyPoint 0000026D2F3A6790>,
#   < cv2.KeyPoint 0000026D2F3A6760>,
#   < cv2.KeyPoint 0000026D2F3A6730>,
#   < cv2.KeyPoint 0000026D2F3A6700>,
#   < cv2.KeyPoint 0000026D2F3A66D0>,
#   < cv2.KeyPoint 0000026D2F3A66A0>,
#   < cv2.KeyPoint 0000026D2F3A6670>,
#   < cv2.KeyPoint 0000026D2F3A6640>,
#   < cv2.KeyPoint 0000026D2F3A6610>,
#   < cv2.KeyPoint 0000026D2F3A65E0>,
#   < cv2.KeyPoint 0000026D2F3A65B0>,
#   < cv2.KeyPoint 0000026D2F3A6580>,
#   < cv2.KeyPoint 0000026D2F3A6550>,
#   < cv2.KeyPoint 0000026D2F3A6520>,
#   < cv2.KeyPoint 0000026D2F3A64F0>,
#   < cv2.KeyPoint 0000026D2F3A64C0>,
#   < cv2.KeyPoint 0000026D2F3A6490>,
#   < cv2.KeyPoint 0000026D2F3A6460>,
#   < cv2.KeyPoint 0000026D2F3A6430>,
#   < cv2.KeyPoint 0000026D2F3A6400>,
#   < cv2.KeyPoint 0000026D2F3A63D0>,
#   < cv2.KeyPoint 0000026D2F3A63A0>,
#   < cv2.KeyPoint 0000026D2F3A6370>,
#   < cv2.KeyPoint 0000026D2F3A6340>,
#   < cv2.KeyPoint 0000026D2F3A6310>,
#   < cv2.KeyPoint 0000026D2F3A62E0>,
#   < cv2.KeyPoint 0000026D2F3A62B0>,
#   < cv2.KeyPoint 0000026D2F3A6280>,
#   < cv2.KeyPoint 0000026D2F3A6250>,
#   < cv2.KeyPoint 0000026D2F3A6220>,
#   < cv2.KeyPoint 0000026D2F3A61F0>,
#   < cv2.KeyPoint 0000026D2F3A61C0>,
#   < cv2.KeyPoint 0000026D2F3A6190>,
#   < cv2.KeyPoint 0000026D2F3A6160>,
#   < cv2.KeyPoint 0000026D2F3A6130>,
#   < cv2.KeyPoint 0000026D2F3A6100>,
#   < cv2.KeyPoint 0000026D2F3A60D0>,
#   < cv2.KeyPoint 0000026D2F3A60A0>,
#   < cv2.KeyPoint 0000026D2F3A6070>,
#   < cv2.KeyPoint 0000026D2F3A6040>,
#   < cv2.KeyPoint 0000026D2F3A6010>,
#   < cv2.KeyPoint 0000026D2F3A5FE0>,
#   < cv2.KeyPoint 0000026D2F3A5FB0>,
#   < cv2.KeyPoint 0000026D2F3A5F80>,
#   < cv2.KeyPoint 0000026D2F3A5F50>,
#   < cv2.KeyPoint 0000026D2F3A5F20>,
#   < cv2.KeyPoint 0000026D2F3A5EF0>,
#   < cv2.KeyPoint 0000026D2F3A5EC0>,
#   < cv2.KeyPoint 0000026D2F3A5E90>,
#   < cv2.KeyPoint 0000026D2F3A5E60>,
#   < cv2.KeyPoint 0000026D2F3A5E30>,
#   < cv2.KeyPoint 0000026D2F3A5E00>,
#   < cv2.KeyPoint 0000026D2F3A5DD0>,
#   < cv2.KeyPoint 0000026D2F3A5DA0>,
#   < cv2.KeyPoint 0000026D2F3A5D70>,
#   < cv2.KeyPoint 0000026D2F3A5D40>,
#   < cv2.KeyPoint 0000026D2F3A5D10>,
#   < cv2.KeyPoint 0000026D2F3A5CE0>,
#   < cv2.KeyPoint 0000026D2F3A5CB0>,
#   < cv2.KeyPoint 0000026D2F3A5C80>,
#   < cv2.KeyPoint 0000026D2F3A5C50>,
#   < cv2.KeyPoint 0000026D2F3A5C20>,
#   < cv2.KeyPoint 0000026D2F3A5BF0>,
#   < cv2.KeyPoint 0000026D2F3A5BC0>,
#   < cv2.KeyPoint 0000026D2F3A5B90>,
#   < cv2.KeyPoint 0000026D2F3A5B60>,
#   < cv2.KeyPoint 0000026D2F3A5B30>,
#   < cv2.KeyPoint 0000026D2F3A5B00>,
#   < cv2.KeyPoint 0000026D2F3A5AD0>,
#   < cv2.KeyPoint 0000026D2F3A5AA0>,
#   < cv2.KeyPoint 0000026D2F3A5A70>,
#   < cv2.KeyPoint 0000026D2F3A5A40>,
#   < cv2.KeyPoint 0000026D2F3A5A10>,
#   < cv2.KeyPoint 0000026D2F3A59E0>,
#   < cv2.KeyPoint 0000026D2F3A5620>,
#   < cv2.KeyPoint 0000026D2F3A55F0>,
#   < cv2.KeyPoint 0000026D2F3A55C0>,
#   < cv2.KeyPoint 0000026D2F3A5890>,
#   < cv2.KeyPoint 0000026D2F3A5860>,
#   < cv2.KeyPoint 0000026D2F3A5830>,
#   < cv2.KeyPoint 0000026D2F3A5800>,
#   < cv2.KeyPoint 0000026D2F3A57D0>,
#   < cv2.KeyPoint 0000026D2F3A56B0>,
#   < cv2.KeyPoint 0000026D2F3A5680>,
#   < cv2.KeyPoint 0000026D2F3A5650>,
#   < cv2.KeyPoint 0000026D2F3A7330>,
#   < cv2.KeyPoint 0000026D2F3A7360>,
#   < cv2.KeyPoint 0000026D2F3A7390>,
#   < cv2.KeyPoint 0000026D2F3A73C0>,
#   < cv2.KeyPoint 0000026D2F3A73F0>,
#   < cv2.KeyPoint 0000026D2F3A7420>,
#   < cv2.KeyPoint 0000026D2F3A7450>,
#   < cv2.KeyPoint 0000026D2F3A7480>,
#   < cv2.KeyPoint 0000026D2F3A74B0>,
#   < cv2.KeyPoint 0000026D2F3A74E0>,
#   < cv2.KeyPoint 0000026D2F3A7510>,
#   < cv2.KeyPoint 0000026D2F3A7540>,
#   < cv2.KeyPoint 0000026D2F3A7570>,
#   < cv2.KeyPoint 0000026D2F3A75A0>,
#   < cv2.KeyPoint 0000026D2F3A75D0>,
#   < cv2.KeyPoint 0000026D2F3A7600>,
#   < cv2.KeyPoint 0000026D2F3A7630>,
#   < cv2.KeyPoint 0000026D2F3A7660>,
#   < cv2.KeyPoint 0000026D2F3A7690>,
#   < cv2.KeyPoint 0000026D2F3A76C0>,
#   < cv2.KeyPoint 0000026D2F3A76F0>,
#   < cv2.KeyPoint 0000026D2F3A7720>,
#   < cv2.KeyPoint 0000026D2F3A7750>,
#   < cv2.KeyPoint 0000026D2F3A7780>,
#   < cv2.KeyPoint 0000026D2F3A77B0>,
#   < cv2.KeyPoint 0000026D2F3A77E0>,
#   < cv2.KeyPoint 0000026D2F3A7810>,
#   < cv2.KeyPoint 0000026D2F3A7840>,
#   < cv2.KeyPoint 0000026D2F3A7870>,
#   < cv2.KeyPoint 0000026D2F3A78A0>,
#   < cv2.KeyPoint 0000026D2F3A78D0>,
#   < cv2.KeyPoint 0000026D2F3A7900>,
#   < cv2.KeyPoint 0000026D2F3A7930>,
#   < cv2.KeyPoint 0000026D2F3A7960>,
#   < cv2.KeyPoint 0000026D2F3A7990>,
#   < cv2.KeyPoint 0000026D2F3A79C0>,
#   < cv2.KeyPoint 0000026D2F3A79F0>,
#   < cv2.KeyPoint 0000026D2F3A7A20>,
#   < cv2.KeyPoint 0000026D2F3A7A50>,
#   < cv2.KeyPoint 0000026D2F3A7A80>,
#   < cv2.KeyPoint 0000026D2F3A7AB0>,
#   < cv2.KeyPoint 0000026D2F3A7AE0>,
#   < cv2.KeyPoint 0000026D2F3A7B10>,
#   < cv2.KeyPoint 0000026D2F3A7B40>,
#   < cv2.KeyPoint 0000026D2F3A7B70>,
#   < cv2.KeyPoint 0000026D2F3A7BA0>,
#   < cv2.KeyPoint 0000026D2F3A7BD0>,
#   < cv2.KeyPoint 0000026D2F3A7C00>,
#   < cv2.KeyPoint 0000026D2F3A7C30>,
#   < cv2.KeyPoint 0000026D2F3A7C60>,
#   < cv2.KeyPoint 0000026D2F3A7C90>,
#   < cv2.KeyPoint 0000026D2F3A7CC0>,
#   < cv2.KeyPoint 0000026D2F3A7CF0>,
#   < cv2.KeyPoint 0000026D2F3A7D20>,
#   < cv2.KeyPoint 0000026D2F3A7D50>,
#   < cv2.KeyPoint 0000026D2F3A7D80>,
#   < cv2.KeyPoint 0000026D2F3A7DB0>,
#   < cv2.KeyPoint 0000026D2F3A7DE0>,
#   < cv2.KeyPoint 0000026D2F3A7E10>,
#   < cv2.KeyPoint 0000026D2F3A7E40>,
#   < cv2.KeyPoint 0000026D2F3A7E70>,
#   < cv2.KeyPoint 0000026D2F3A7EA0>,
#   < cv2.KeyPoint 0000026D2F3A7ED0>,
#   < cv2.KeyPoint 0000026D2F3A7F00>,
#   < cv2.KeyPoint 0000026D2F3A7F30>,
#   < cv2.KeyPoint 0000026D2F3A7F60>,
#   < cv2.KeyPoint 0000026D2F3A7F90>,
#   < cv2.KeyPoint 0000026D2F3A7FC0>,
#   < cv2.KeyPoint 0000026D2F3D0030>,
#   < cv2.KeyPoint 0000026D2F3D0060>,
#   < cv2.KeyPoint 0000026D2F3D0090>,
#   < cv2.KeyPoint 0000026D2F3D00C0>,
#   < cv2.KeyPoint 0000026D2F3D00F0>,
#   < cv2.KeyPoint 0000026D2F3D0120>,
#   < cv2.KeyPoint 0000026D2F3D0150>,
#   < cv2.KeyPoint 0000026D2F3D0180>,
#   < cv2.KeyPoint 0000026D2F3D01B0>,
#   < cv2.KeyPoint 0000026D2F3D01E0>,
#   < cv2.KeyPoint 0000026D2F3D0210>,
#   < cv2.KeyPoint 0000026D2F3D0240>,
#   < cv2.KeyPoint 0000026D2F3D0270>,
#   < cv2.KeyPoint 0000026D2F3D02A0>,
#   < cv2.KeyPoint 0000026D2F3D02D0>,
#   < cv2.KeyPoint 0000026D2F3D0300>),
#  array([[  3.,  15., 110., ...,   0.,   0.,   0.],
#         [ 22.,   1.,   0., ...,   1.,   0.,   0.],
#         [ 55.,   2.,   0., ...,  17.,   0.,   0.],
#         ...,
#         [  1.,   1.,   0., ...,   0.,  21., 141.],
#         [  0.,  89., 144., ...,   0.,   0.,   0.],
#         [  0.,   0.,   0., ...,   0.,   0., 140.]], dtype=float32))

# %%
kp, des = sift.compute(gray, kp)
