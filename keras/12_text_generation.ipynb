# %% [markdown]
# # Text generation

# %% [markdown]
# Reweighting a probability distribution to a different temperature.
#
# original_distribution is a 1D NumPy array of probability values that must sum to 1. temperature is a factor quantifying the entropy of the output distribution.
#
# Returns a reweighted version of the original distribution. The sum of the distribution may no longer be 1, so you divide it by its sum to obtain the new distribution

# %%
import numpy as np

def reqeight_distribution(original_distribution, temperature = 0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution / np.sum(distribution)

# %% [markdown]
# ##  Data preparation
# https:/ /ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz

# %%
import tensorflow as tf
from tensorflow import keras
dataset = keras.utils.text_dataset_from_directory(
    directory="aclImdb", label_mode=None, batch_size=256)
dataset = dataset.map(lambda x: tf.strings.regex_replace(x, "<br />", " "))
# Out:
# Found 100006 files belonging to 1 classes.

# %%
from tensorflow.keras.layers import TextVectorization

sequence_length = 100
vocab_size = 15000
text_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length,
)
text_vectorization.adapt(dataset)

# %%
# Convert a batch of texts (strings) to a batch of integer sequences.
def prepare_lm_dataset(text_batch):
    vectorized_sequences = text_vectorization(text_batch)
    x = vectorized_sequences[:, :-1]
    y = vectorized_sequences[:, 1:]
    return x, y

lm_dataset = dataset.map(prepare_lm_dataset, num_parallel_calls=4)

# %%
lm_dataset = dataset.map(prepare_lm_dataset, num_parallel_calls=4)

# %% [markdown]
# ## A TRANSFORMER-BASED SEQUENCE-TO-SEQUENCE MODEL

# %%
import tensorflow as tf
from tensorflow.keras import layers

class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, input_dim, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=input_dim, output_dim=output_dim)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim)
        self.sequence_length = sequence_length
        self.input_dim = input_dim
        self.output_dim = output_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

    def get_config(self):
        config = super(PositionalEmbedding, self).get_config()
        config.update({
            "output_dim": self.output_dim,
            "sequence_length": self.sequence_length,
            "input_dim": self.input_dim,
        })
        return config


class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
          num_heads=num_heads, key_dim=embed_dim)
        self.attention_2 = layers.MultiHeadAttention(
          num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def get_config(self):
        config = super(TransformerDecoder, self).get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1),
             tf.constant([1, 1], dtype=tf.int32)], axis=0)
        return tf.tile(mask, mult)

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(
                mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)
        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=causal_mask)
        attention_output_1 = self.layernorm_1(inputs + attention_output_1)
        attention_output_2 = self.attention_2(
            query=attention_output_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        attention_output_2 = self.layernorm_2(
            attention_output_1 + attention_output_2)
        proj_output = self.dense_proj(attention_output_2)
        return self.layernorm_3(attention_output_2 + proj_output)

# %%
from tensorflow.keras import layers
embed_dim = 256
latent_dim = 2048
num_heads = 2

inputs = keras.Input(shape=(None,), dtype="int64")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, x)
outputs = layers.Dense(vocab_size, activation="softmax")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop")

# %%
import numpy as np

tokens_index = dict(enumerate(text_vectorization.get_vocabulary()))

def sample_next(predictions, temperature=1.0):
    predictions = np.asarray(predictions).astype("float64")
    predictions = np.log(predictions) / temperature
    exp_preds = np.exp(predictions)
    predictions = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, predictions, 1)
    return np.argmax(probas)

class TextGenerator(keras.callbacks.Callback):
    def __init__(self,
                 prompt,
                 generate_length,
                 model_input_length,
                 temperatures=(1.,),
                 print_freq=1):
        self.prompt = prompt
        self.generate_length = generate_length
        self.model_input_length = model_input_length
        self.temperatures = temperatures
        self.print_freq = print_freq

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.print_freq != 0:
            return
        for temperature in self.temperatures:
            print("== Generating with temperature", temperature)
            sentence = self.prompt
            for i in range(self.generate_length):
                tokenized_sentence = text_vectorization([sentence])
                predictions = self.model(tokenized_sentence)
                next_token = sample_next(predictions[0, i, :])
                sampled_token = tokens_index[next_token]
                sentence += " " + sampled_token
            print(sentence)

prompt = "This movie"
text_gen_callback = TextGenerator(
    prompt,
    generate_length=50,
    model_input_length=sequence_length,
    temperatures=(0.2, 0.5, 0.7, 1., 1.5))

# %%
model.fit(lm_dataset, epochs=200, callbacks=[text_gen_callback])
# Out:
# Epoch 1/200
# 391/391 [==============================] - 2100s 5s/step - loss: 5.3558
# == Generating with temperature 0.2
# This movie does is english a and subtle if [UNK] i effect know before the step movie an away evening the after background a  few years ago get involved in new [UNK] junk reached the woods who drive to their rich babe determined well  is and allison principals russian marx
# == Generating with temperature 0.5
# This movie movie wasnt is hard full many offend of ashes players of can civilization be with a the certain comic issues worlds eg by cutter jazz town business the grossout atlantic children which the are doors two for different their the flashbacks deal we with are ensues familiar what sets films
# == Generating with temperature 0.7
# This movie movie is was like flat she especially may said recommend her heiress small drew green barry sinister mannerisms as are the in future desi operative death in by help an to incredibly a good week as very a believable virtual and this ego flick meet from a his collage music
# == Generating with temperature 1.0
# This movie did may see be it or pour less speaking if chance cried to his the setting latter was less a often commentary other on than [UNK] this [UNK] film the [UNK] downtown a i conflicted know suggests the another first major two spoilers brilliantly ive [UNK] seen upon trial and
# == Generating with temperature 1.5
# This movie movie is quite absolutely interesting great around on character so and cherry lucy henson international however favorite this big way line as and three [UNK] americans character are sleeps most is loud not torture offended sequences by come others up [UNK] your them seat instead this but film generally does
# Epoch 2/200
# 391/391 [==============================] - 1978s 5s/step - loss: 4.8137
# == Generating with temperature 0.2
# This movie is was incredible funny it however is i about myself 18 never hours forgot of little life extra since lock i stock attended footage an and animation was 1 hailed am as jaded an enough art to stage cancel more the cable plot tv to show famous their culture assistant
# == Generating with temperature 0.5
# This movie starts is to ill the also absolute continually dialogue reminded contains me comic of im the sure scenes cliche are point going and fred buying [UNK] an much invasion better those than before 10 they years payed later nothing thousands not of before money long to before watch there seven
# == Generating with temperature 0.7
# This movie short is story fair of the a little great girl name anna the [UNK] plot [UNK] before a the la diva end [UNK] with mask another and one poirot approached is by the anyone magnificent who in ends the up absence alive of and vain so for if any one
# == Generating with temperature 1.0
# This movie movie felt is really unbelievable weird the and only enjoyable criticism id its be your plot dvd to [UNK] be entertain [UNK] a without selfindulgent knowing it anything was about thats sadako r it mine injured so and my beaten mother up [UNK] more yeah than music that the youll
# == Generating with temperature 1.5
# This movie movie was plods terrible along plot a concerns way some middle high and class once answers the that pacing learn is that praised the for issue a the war can 3 take children pakistan at a hollywood healthy video tenant store in and if being youre sold aware to [UNK]
# Epoch 3/200
# 391/391 [==============================] - 1968s 5s/step - loss: 4.5923
# == Generating with temperature 0.2
# This movie is was tragic painful moving its and the light twist ray you was need not to expressed see in catherine this valley genre curious where history she teacher raised has by some mentioning kind foreign of film work [UNK] with cast the of old [UNK] cliché the in film front
# == Generating with temperature 0.5
# This movie is is utterly definitely melodrama a its testament premise and as really to basically being obrien trying i to can tell live a outside lot of of give strange truth connections to and the the part standout where in shallow the transition need of of the episode characters unfortunately are
# == Generating with temperature 0.7
# This movie was is completely so 90 boring minutes i used got to no see idea that james if [UNK] characters a had monster ever based told on it michael it baxter from matt france [UNK] play exceedingly his predictable batman and and diverse ginger character lynn seems could to barely act
# == Generating with temperature 1.0
# This movie movie is caused horrible some valley stupid moments rules especially things a [UNK] worthy boy holiday arrogance and gore yours [UNK] thats supposedly not due funny to technology how but uninspired for can the eugene whole levy movie forced on unfunny it skeleton just man makes i a have giant
# == Generating with temperature 1.5
# This movie was is in one simple of its the ideas best that of can reels be i base had of to the deal first of time history in ryan greek was stewart also and the dean material balanced that manner turned that out lead into characters some commits technical as details
# Epoch 4/200
# 391/391 [==============================] - 1966s 5s/step - loss: 4.4671
# == Generating with temperature 0.2
# This movie movie was is [UNK] so bad naturally you it most is [UNK] possible i and want was to in like high this school one is was the really cover good tape [UNK] is directing very fantastic [UNK] and [UNK] [UNK] is not the what story is plot so is normal
# == Generating with temperature 0.5
# This movie movie is was really too like much carrie the story movie was starts really out like like makes it many look action tom and places you very dont familiar have the to [UNK] each the other story a is government hackneyed organization and working leaving as its a due surreal
# == Generating with temperature 0.7
# This movie show is wasnt [UNK] dark at it first all came because out it it [UNK] is the most writer important decided issues to are make missing some a of sequel the is movie brilliant allen it and stars i great thought care this of meant id for be the good
# == Generating with temperature 1.0
# This movie is was basically de about niro three making horrible their and families slightly together different on stories the the other issues both but are the left length behind directed it produced is a comeback total film worthless about and an the almost dialogs talentless are characters so are smoothly bad
# == Generating with temperature 1.5
# This movie movie was is horrible all b i 90s would china like with [UNK] a didnt [UNK] match waste the so plot everybody was is ghost a in real complete life with that so really if bad they a put [UNK] lunch a time waiting think on about any the of
# Epoch 5/200
# 391/391 [==============================] - 1991s 5s/step - loss: 4.3800
# == Generating with temperature 0.2
# This movie is sucked about i a saw hard assembled for in this a forgot good account change of it new the difficulty cinematography depicted is value what and might how have the happened presenting to a [UNK] forest rap this on movie your not eye a but single if mother you
# == Generating with temperature 0.5
# This movie is is up mildly to interesting originality points maybe toward a the ghost audience world with something lots going of over you every awry time our it [UNK] must what be this the a storyline masterpiece and i hope think and back more youll sinister see [UNK] cost [UNK] of
# == Generating with temperature 0.7
# This movie may could have have been been a better good rko movie notorious it for would years have after been movie [UNK] career fortunate attempts with at many ms points m and is [UNK] timeless the aside least from bit completists where although  we must have [UNK] and amos [UNK]
# == Generating with temperature 1.0
# This movie movie contains is suspense all thriller it movies is out just in a all fist around but it full is of and john end carradine but plays the a granny married who to lives vietnam in prison one for of an her over symbol arrived former on doctor the and
# == Generating with temperature 1.5
# This movie is may based not on by the an comic acceptable strip las from vegas the to same this extent falls that apart kennedy was tries murdered to by be goldie fine hawn actor making hunt it as terribly a [UNK] psychotic to gambling give and great armageddon oneliners a that
# Epoch 6/200
# 391/391 [==============================] - 1963s 5s/step - loss: 4.3141
# == Generating with temperature 0.2
# This movie is is awesome the the way acting racing just went right to from topics [UNK] to and the the first notch time part also of and what the really where got the so love called story and too how i many liked others the i scene had i to loved
# == Generating with temperature 0.5
# This movie movie really is kept bad me when it you picks have the the suspense story and it the just lead staring character [UNK] who get is the out characters of are time separated the because story she is wanted so to she be dies forgot in her the life ending
# == Generating with temperature 0.7
# This movie is is predictable about lately the a plot great line scenery of acting london and and it two makes people the wrong real people life of if life the separated three sadie men see and [UNK] women around over in the eastern entirety scenery and of help course thats its
# == Generating with temperature 1.0
# This movie is changed brilliant so so bad [UNK] its intelligent got and annoying enjoyable the what characters a the cardboard pace [UNK] and over got by a what [UNK] does banter not really work bad [UNK] if the viewers plot were is more it costume then than its the not guy
# == Generating with temperature 1.5
# This movie is is a good sequel a or storyline a that bunch should of be had able i to clearly say expected that something it really was did better not even waste work this the first [UNK] time had i to almost myself ended in up my having eyes the with
# Epoch 7/200
# 391/391 [==============================] - 1964s 5s/step - loss: 4.2613
# == Generating with temperature 0.2
# This movie movie actually was actually entertaining pretty too much 30 i at thought this it might could be be good something unfortunately it it didnt got deliver a the nuclear plot [UNK] of and col going im to hunting be for ignored their thats grisly how starts series happening ended flashback
# == Generating with temperature 0.5
# This movie movie 1986 is 1970 almost carter phenomenal the and funniest powerful movie spoof i of ever many saw people over at 100 the girls front friend of 1940 death 3 and was not a very cartoon disappointing [UNK]  the plot was ashley was well remember they did it for
# == Generating with temperature 0.7
# This movie western may is not not very for good an randall avid shannon reader lee will which be be if remembered not as from huge the stars legendary instead naschy of sorry his actor outing lawrence as tierney a but square great gets king boring was calm quirky and and dull
# == Generating with temperature 1.0
# This movie movie has reminded ed me divided of into 2 my weeks summary i of knew guilt these and films essay constantly one ratings day for for awhile me although with almost soap two opera women singers who included might both say [UNK] and each ritter is might easily suspect do
# == Generating with temperature 1.5
# This movie movie is sucks made simply and out will of actually all fight it acts means like hate william it billy [UNK] thornton fetish watch herman a street bad trash actor movie im here not and half there there have are been several many [UNK] blaxploitation in movies his [UNK] reputation
# Epoch 8/200
# 391/391 [==============================] - 1965s 5s/step - loss: 4.2170
# == Generating with temperature 0.2
# This movie is was a not good a movie movie but for very third long why it i had woke 2 up months of later my a love night [UNK] not [UNK] even it consider never finding even an that invincible seen urge by to a come bad together viewer in can
# == Generating with temperature 0.5
# This movie was should a have suck left with it the this theater movie in follows a the car cliché which right i into would the think least that 23 it is may three have times named possible this if movie you gets have involved a in guy a and [UNK] other
# == Generating with temperature 0.7
# This movie [UNK] happened the very blair early witch 80s project great blair deal gets was you never sorry really that stupid but confused that and italian the [UNK] hell movie is [UNK] endlessly [UNK] the nonsense character of development both and human it and had original nothing actors to the star
# == Generating with temperature 1.0
# This movie is is a probably perfectly [UNK] officer comment who on can anything be as said made by for a [UNK] tv with movie a am front and from i airplane like no split other with than road species movies this as is shown not on to dvd different for until
# == Generating with temperature 1.5
# This movie short is was a my search duty the to original make the us kids government pass secrets its [UNK] funny flesh a out lot that many will where pretend to these be people just either want [UNK] to or get since their i own feel all for the about broken
# Epoch 9/200
# 391/391 [==============================] - 1974s 5s/step - loss: 4.1794
# == Generating with temperature 0.2
# This movie has was earned promising dont it get is this house silly of little a horror little movie horror [UNK] house but story when this i puppet saw directorwriter it peter again cushing that is coop pretty [UNK] poor the [UNK] kids [UNK] are an allowed investment access in to commercials
# == Generating with temperature 0.5
# This movie is left great entirely scenery in breathtaking this in [UNK] dietrich generation and in has general a contact few for of her the and films the many day critics have have already said commented that [UNK] its masterpiece spoiler [UNK] so [UNK] here [UNK] an is old an film exceptional
# == Generating with temperature 0.7
# This movie existed is on almost lifetime every with single tragic guns inherent and classics racing i dont mean doubt that even the party last system piece [UNK] of hey movie someone most [UNK] people lsd have trip all to their see [UNK] film by from the any old hong american kong
# == Generating with temperature 1.0
# This movie is made an up impression on on me video i at know the movies start from of the about latin filming ethnic on films movie such inner as world that war their is actions very most simple important and and yet accurate touching portrayal precious of from our the countrys
# == Generating with temperature 1.5
# This movie movie remains is the hilarious worst rating movie ever i had ever no seen idea it how was many it positive left comments the about source grandfather of frank his sinatra youth fan was watching mixed all up assure and [UNK] made to his work work i apart really the
# Epoch 10/200
# 391/391 [==============================] - 2007s 5s/step - loss: 4.1470
# == Generating with temperature 0.2
# This movie film is was meant confusing to and watch [UNK] a after perfect screening one i could cant have fault noticed with what it could is easily not good with the the [UNK] film script capital is drama predictable is and only the to mexican be cinema described tell here us
# == Generating with temperature 0.5
# This movie movie is was so extremely bad low it budget wasnt should too the much actors is were horrified in the movie audience the never worst actually it boring is the boring movie talk has about all it the even dialog at characters the clumsy plot camera is angles so and
# == Generating with temperature 0.7
# This movie movie is is the outstanding best acting for production many in [UNK] my viewers rating have this a movie 1 is and a makes straight it to more the than actors 20 it or may more i you promise are very not familiar given with the the character book i
# == Generating with temperature 1.0
# This movie film mini is series really first very in bad ways terms its of very reality good the the story first is part dreary of and characters looks made like the all film star work of in the the movie cast are some so of lovely us ladies in and the
# == Generating with temperature 1.5
# This movie [UNK] was i amazing really it need is we a need kid and to the follow soundtrack them this through movie im is giving kinda you high another on kung earth fu atmosphere duke all is the awesome second a time disappointment this a movie movie ive has got the
# Epoch 11/200
# 391/391 [==============================] - 1975s 5s/step - loss: 4.1182
# == Generating with temperature 0.2
# This movie is was probably basically the the strangest idea movie was in where the [UNK] murders fail ruled to the barry silence [UNK] seeks attempts rightly on and anyones been control an and extended tries [UNK] to moustache [UNK] which before he and and his tries targets to he get finds
# == Generating with temperature 0.5
# This movie primarily sucked because part of in what appearance it she made learned playboy about 20 the years problem ago the and film more was than certainly fighting good with nut the who script certainly wrote turns these perry actors were will lays just bare not breast one milk night the
# == Generating with temperature 0.7
# This movie is is very plain complicated awful and british peaceful film life industry what an makes 810 others trash from industry unimaginative this directing one i uninspired dont filmmaking mind the four story cigarettes is when beyond youre belief skilled early and on then the watch editing the released stilted in
# == Generating with temperature 1.0
# This movie attempt really to should be be obvious put at on a everything second spoken but dialogues is are a totally bit ruin slow leaving for everyone anything while is being [UNK] disappointed i that did the not movie in have a the heartless cinematography sugar was with your little heart
# == Generating with temperature 1.5
# This movie film was shares actually with a its mainstream story style but of within the its genre beginning population afternoon film iv noir the thriller subject was is interesting a and true amazed promise by to director the aspect leroy of [UNK] the [UNK] proceedings types from throughout the movie film
# Epoch 12/200
# 391/391 [==============================] - 1967s 5s/step - loss: 4.0937
# == Generating with temperature 0.2
# This movie is billed beautiful as but the it locations is are not strictly everything for going christianity and but it featuring does all its the status clothes we if beginning 1984 visually then as this the 40 cause year it award is winners quite high literally fever doing but what the
# == Generating with temperature 0.5
# This movie film has was been everything charles about isnt the an best ordinary of soap his [UNK] new and bride thats were it in met fact if an it european lived star our power sport cold stereotypes war colored had rich i characters [UNK] like me while [UNK] this on is
# == Generating with temperature 0.7
# This movie unfunny was is another just pointless hide dumb from and the if need [UNK] to [UNK] make into great something comedy i and almost everyone scream loves i dead love tongue seeing if many you books dont never i have recommend worked you on think it i is strongly just
# == Generating with temperature 1.0
# This movie is is kinda a of failure a is film to to save be the [UNK] film gangs makers though for dead government just et wants al bud to story take but another boy stop is but as the many film odds makers are are never here too them special to
# == Generating with temperature 1.5
# This movie sequel literally [UNK] took [UNK] the from film work was with [UNK] delight [UNK] by action largely the when original in [UNK] the ii original version friday was the great original entry with in ralph the bakshi sequel version to [UNK] thomas but [UNK] ironically [UNK] one despite of being
# Epoch 13/200
# 391/391 [==============================] - 1978s 5s/step - loss: 4.0713
# == Generating with temperature 0.2
# This movie show is is fabulous absolutely it perfect has the if acting [UNK] shows talent that and so not brilliantly to helmed create that an he excellent barely movies below it what is i truly dont intrigued expect from these such films human the behavior way and it a explores man
# == Generating with temperature 0.5
# This movie is used really as nasty people as think being the a only hindi an movie showed there how a to lot remain of [UNK] soft against core the restoration movies of  this kind infested with crime on the road as guessing relation did then so i had to hold
# == Generating with temperature 0.7
# This movie is gives so you much a at feeling its very initial different second than in the [UNK] last but 30 [UNK] minutes this of time [UNK] i big got bug to on watch the [UNK] dvd [UNK] of up the it later beforehand i through is the the beast da
# == Generating with temperature 1.0
# This movie movie constantly just stole cheap my story heart has i an was hour glued into to my watching seat it instead [UNK] of it the because brutal they stereotypical sometimes cerebral manage [UNK] to controlling express [UNK] how but many a anyone director says and that just maybe does i
# == Generating with temperature 1.5
# This movie movie was clearly possibly intended the to feeling be that only each shows person effect makes every something aspect very of enjoyable the is entire the physical way aspect even of if their they highschool will patients make experience thinking with when a they [UNK] would in watch pretty his
# Epoch 14/200
# 391/391 [==============================] - 1976s 5s/step - loss: 4.0515
# == Generating with temperature 0.2
# This movie movie probably made had hepburn a [UNK] lot theme before it the gets story back it on became silver one was of a the top only studio pink [UNK] [UNK] and for the the scene 30s at with the katharine last hepburn which didnt dealt speak with the this hands
# == Generating with temperature 0.5
# This movie show was some released [UNK] in only australia 16 was more a than [UNK] 30 [UNK] minutes thats could probably easily not have be been produced said that about it your there comments is like zero me emotion one in day all one the of funny the lines dumb not
# == Generating with temperature 0.7
# This movie movie couldnt told live me me enough at to [UNK] get in it my he head could it a should movie know be what a happened movie although is some nothing of creative the creative scenes team come and like well [UNK] apart this unlike one behind has any better
# == Generating with temperature 1.0
# This movie has was more not than intended drawn to to the its [UNK] own protagonist vision but and to it the every story one was may a need little to more die whether for or die not in treated that ratings it the was world quite of filling the up marvelous
# == Generating with temperature 1.5
# This movie is is a terrible complete love waste story of there two is beautiful not women even everything close else to to an actors antiwar work pleasure in rating this a movie 2 that stars is some so reviewers bad tend i to do participate this of movie another if 48
# Epoch 15/200
# 391/391 [==============================] - 1979s 5s/step - loss: 4.0336
# == Generating with temperature 0.2
# This movie horror is masterpiece about low a budget middle production class values but but the thats most odd people considering either seeing cheat this a film scene or doesnt things stop dont them seem though like one a of bunch the of drug population sequences hightech are taking just drugs phone
# == Generating with temperature 0.5
# This movie movie was claims like an a afterlife john [UNK] criticizing tradition the revenge first of one dr [UNK] [UNK] charles along travis with puts his his own head ride down in protected a by 100 priests studying [UNK] the [UNK] civil [UNK] war drugs movie and blood some following truly
# == Generating with temperature 0.7
# This movie actually was made marginally for better cohen actors ive in [UNK] many blood movies and with guts a and few excitement shots anticipation thrown the out plot of with the a cops bunch working of in criminals rubber a shocked killer porno marathon rapist man is who forced his to
# == Generating with temperature 1.0
# This movie was stinks a more qualified camp a cartoon low that budget is [UNK] shown between as [UNK] a this television movie movie was it turned supposed into effort a to the present syrupy doctor esoteric no traditional inducing script horror and comes occasional across lighter as fluid [UNK] if to
# == Generating with temperature 1.5
# This movie movie in is my the opinion first between excellent luke features wilson both spencer [UNK] marshall and him seth they [UNK] take it a over near six the mins weekend tradition there it are was hilarious a moments few where witty mickey jokes wrap and with how it else is
# Epoch 16/200
# 391/391 [==============================] - 1978s 5s/step - loss: 4.0170
# == Generating with temperature 0.2
# This movie movie was really just so so awful so and much so [UNK] horrible are and the just poorly so made they that had they changed [UNK] [UNK] to the make [UNK] up they as were cgi they [UNK] [UNK] they this were movie [UNK] switzerland was and back ive in
# == Generating with temperature 0.5
# This movie is is great a for basic anyone women like who me can this agree real with was the that [UNK] it was kept charming going and interestingly sweet enough and they not could to have afford done a a prize lot with but a when sweet she [UNK] wanted she
# == Generating with temperature 0.7
# This movie movie is is the incredibly epitome lousy of with new ridiculous ideas ideas and and came [UNK] together etc a the handheld worst camera movie work ever ever so oh bad from as start to you finish wonder in if their sheep eyes makes the them fight so with many
# == Generating with temperature 1.0
# This movie title about paris a is soldier the trying other to desperately smiles try and to prove keep effective her but the this wrong movie time was it a a chick not flick in to the mention extent the of characters the as [UNK] a are big called bunch but of
# == Generating with temperature 1.5
# This movie is is okay a and lot deserves more younger credit directors than since everyone im should still credit be it the is first not movie as i it understand may why be this a the bad funniest guy movie especially at for the critics child as chick a who guy
# Epoch 17/200
# 391/391 [==============================] - 1974s 5s/step - loss: 4.0021
# == Generating with temperature 0.2
# This movie flick is is a one [UNK] [UNK] in lower it quality its than set the in standard space almost type [UNK] mode war there movie is is to the record standard all side of story it content by is creating just a a unique noir perspective type on of the
# == Generating with temperature 0.5
# This movie is is as not [UNK] as its a message mediocre of [UNK] a the night acting of showcase rukh even the more director beauty he than has not to even be come turned close the to movie one and of makes its the share best of closeups a of featured
# == Generating with temperature 0.7
# This movie movie did is not really a about airport a manhattan girl [UNK] named destroying [UNK] the ever room mentioned and but saying in kick the a first [UNK] thing this all movie of had which [UNK] was in really the heaven world but of it movies were making all and
# == Generating with temperature 1.0
# This movie movie made should a be complete a waste second of the editing first there movie is so so little little to action spend but all no in time it to could incredible have this been also in what a was waste trying of to a make single out it their
# == Generating with temperature 1.5
# This movie is dared kind to of be like a [UNK] true eating story a about small two home boys due in to the its [UNK] part and and is its what garage happens to when be it the is kid not meets at this no school piano the teacher movie to
# Epoch 18/200
# 391/391 [==============================] - 1974s 5s/step - loss: 3.9883
# == Generating with temperature 0.2
# This movie movie has was a basically great true main story character of jake jim cohen carrey john has gets been angry a a hooker cockney and himself [UNK] mike by service the with latter his class captors and this the movie bird gets is a just bit splendid sad i because
# == Generating with temperature 0.5
# This movie movie is starts absolutely very bad bold but goes getting south it the leads action are with finally affairs exception with its two title ladies actors they that are have dealing gone with before shooting but it who a cares crooked to cops build the their main one storyline hand
# == Generating with temperature 0.7
# This movie is scared just out keep of away it from is what poorly it scripted is 5 so years hours apart long from and me that i i can notice wait that till baby it is also on on video dvd the and possible almost copy made asking it the to
# == Generating with temperature 1.0
# This movie film is is like no a survive point or of two view men three battle men in escape the finishing movement absence gregory of peck english my act mother very is strong deeply with who parts has later what components lee of van the [UNK] acting movie is this hitting
# == Generating with temperature 1.5
# This movie is looked a excellent bit no on cassavetes daytime except soaps most it errors feels in like a i rare saw look it on was video a when couple men of run men together showing in their the commercials mid and 1960s out at of one his scene best where
# Epoch 19/200
# 391/391 [==============================] - 1978s 5s/step - loss: 3.9760
# == Generating with temperature 0.2
# This movie stopmotion was monastery just and last it a never [UNK] had the rented cheapest earlier film [UNK] of of the the worst thousands modern of world [UNK] war cool ii only is a the super first silly film style that [UNK] like [UNK] preparing was for the the master guy
# == Generating with temperature 0.5
# This movie film is took about a a cat so even i if saw there the is producers a name story only of to that get expectation what [UNK] i universal wish created that as novels a as message good to acting the with [UNK] very plot good that casting although is
# == Generating with temperature 0.7
# This movie dunne is really an a oscar nice winner concept but and the the characters way are over of and change over they the all acting are is in such this a movie [UNK] since of the the late story 60s is middle a class tv [UNK] movie  comedian and
# == Generating with temperature 1.0
# This movie film was is made truly in bad [UNK] take acting the lessons [UNK] of 1984 the and only the [UNK] names academy ive award seen that her [UNK] performance [UNK] in [UNK] 30 [UNK] years production during did the i cinematography mention was the original [UNK] and made the a
# == Generating with temperature 1.5
# This movie had is i a didnt [UNK] understand for all background ages information 5 and of i them am watch in them your almost own my way video it are is usually very very [UNK] exciting by living the bonus normal features people of it the used director to but do
# Epoch 20/200
# 391/391 [==============================] - 1993s 5s/step - loss: 3.9645
# == Generating with temperature 0.2
# This movie is follows a in anita [UNK] colors some and dope heather how graham sad can result really with get terms divorced of aside a from slapstick this to [UNK] movie and [UNK] [UNK] not itself much outside humor of nor the romantic freedom plot it [UNK] is but laughably the
# == Generating with temperature 0.5
# This movie is sets not are within pathetic [UNK] people but walked realistic together and with very the talented director remaining a did fantastic he job contacts he a wore bum a sorts boat of alright dying traveler red is from the time considerable travel achievement from so la earlier land i
# == Generating with temperature 0.7
# This movie would has make been me more since frustrated i because felt of like what being i in perceived heaven certain i are think blown of away sheer reflected luck part kevin fired costner is appears chief in bloated small [UNK] part portrayal in i hitchcock focus was caricature no and
# == Generating with temperature 1.0
# This movie is is good a in lot this of way independent its movies not like just the a way race lesson but for also being the happy two the eventually cast die members the die gang hard heads with find plenty orson of welles easy blended to ash mentally gorgeous challenged
# == Generating with temperature 1.5
# This movie is sucked a out bit of good a taste kick there like just waiting be it get all worse the they acting dont was read bad subtitles in though all quality of were their ok very concepts good are performance certain rating things acceptable in on all papers involved mean
# Epoch 21/200
# 391/391 [==============================] - 2003s 5s/step - loss: 3.9540
# == Generating with temperature 0.2
# This movie movie is was terrible enjoyable at it first with start a i young dont man think out there good wwii acting doesnt was require horrible [UNK] acting to no deliver degree top and but it i was ended very up disappointed joshua that [UNK] bruce i and was his in
# == Generating with temperature 0.5
# This movie movie was was the pretty answer bad to but movies was is really somebody bad making movie cool and and good it bad doesnt but try the to one good get one 0 person out 2 of what 10 was rating the [UNK] rest was of just the awful fact
# == Generating with temperature 0.7
# This movie movie is on about my about allow half me to to come explain upon and i watching personally your on [UNK] top and of watch the the theater [UNK] from minutes the worth movie and alone you the cant rest pop of it the this [UNK] movie well just as
# == Generating with temperature 1.0
# This movie movie is makes actually you feel hate for to the bad low guys rating the this city movie is on about every 4 aspect hour of there the is movie nothing that that a made movie some that of good the movies bad are editing crappy 4 i i wish
# == Generating with temperature 1.5
# This movie was was a about [UNK] two girl years toni ago collette at when the her script dad was was thinking an on actor a award good i stealing loved jack the dies kid from wanted [UNK] mostly earlier because be he i was watched asked the to movie stay [UNK]
# Epoch 22/200
# 391/391 [==============================] - 2005s 5s/step - loss: 3.9438
# == Generating with temperature 0.2
# This movie is was epic a 1960s classic series i credit saw the it late was 60s really huh concerned for with its acting bad storytelling story maybe robots it can was be filmed discussed often stuff they and just used couldnt information moms on totally the gross material pact did complete
# == Generating with temperature 0.5
# This movie film is is wonderful supposed we to start start to watching consider it an still accident hunter after does an a excellent missionary job turns in the an fall intense for especially gregory [UNK] too terrific strange performances and from [UNK] [UNK] pool acting brings as his to wife us
# == Generating with temperature 0.7
# This movie is didnt currently make intended to as be a fun sequel movie to one the of name [UNK] its is name the always accident relevant that today the bomb previews [UNK] are box taken office from office the secretary [UNK] celebrity [UNK] days [UNK] in said horror this movie movie
# == Generating with temperature 1.0
# This movie movie reminds truly me a how cast class were of [UNK] actors in even this movie movie did being not poor spiritual for any me reason was i this talked was about because wondering id who awfulness now her im from a chicago [UNK] grade i school thought age then
# == Generating with temperature 1.5
# This movie film was left absolutely almost little entirely when unlike i another tuned user in flavor while footage it had was some shot of at snow any [UNK] ethnic its lesbian [UNK] dimensions realism and no the can ending be without found being in repeated fact out [UNK] for rumors example
# Epoch 23/200
# 391/391 [==============================] - 1989s 5s/step - loss: 3.9346
# == Generating with temperature 0.2
# This movie is was about a a study religious of will exchange smith your and name definition have hall lost balls everything of he easy already answers told back me that its a the rare happy story days about no people other and film every although depicted this in can the be
# == Generating with temperature 0.5
# This movie movie is [UNK] [UNK] funny was and [UNK] computer started animated the and fight many scenes actions were the filled best [UNK] moments [UNK] were manner apparently a the [UNK] [UNK] film got had a [UNK] real [UNK] title of cheaply a made werewolf for the a screen quick daughter
# == Generating with temperature 0.7
# This movie is is so always lame its but like great a movies bad [UNK] plot there people is go totally on wrong the side plot the is beginning almost of amazing the acting whole is cast so all good that a it good though gags for most mental of illness the
# == Generating with temperature 1.0
# This movie movie makes was a good lot its of great andy fun garcia but was the a best great in character such and a mrs wonderful mirren setting out as strip [UNK] for with daylight her dollars eyes jennifer shes [UNK] also daughter outstanding of from her the [UNK] rest place
# == Generating with temperature 1.5
# This movie is is a sometimes ripoff [UNK] of and this the movie result along is by in far jail more but some its movies more like gory this killings is are rather not good used as to some be but the i subtitle expect has the most [UNK] [UNK] in for
# Epoch 24/200
# 391/391 [==============================] - 1992s 5s/step - loss: 3.9262
# == Generating with temperature 0.2
# This movie movie was sucked hilarious into only an laughing passable [UNK] acting at here least were comedic some the of european the actors characters were were hardly very likable dramatic they and mostly of quite course natural johnny and depp what core a pie stinker maker i having wonder yet if
# == Generating with temperature 0.5
# This movie is is just an horrible embarrassment movie to bitch tears and unless win you any understand award positions winners in feature one films of decline whom because for its true lack nature of whatsoever imagination the and heroine irony is is a forced crawl waste and of a everyones cheap
# == Generating with temperature 0.7
# This movie movie sucked is for lousy women acting the effects humor are the terrible norm what or makes whats this worse movie it on is television that its of just those tapes places label need call in it style porn no and light makes so this many comment more on to
# == Generating with temperature 1.0
# This movie show is mask horrible review the its kills actually from a the 3 story i is like probably that watches it this several series times have far to too be many there fan are saying st but [UNK] if dreams youre come watching the or series not what for gore
# == Generating with temperature 1.5
# This movie is has absolutely the lot flawless of who the the creators original cant novel be out bothered of to even write spoken a dialog perfect like dialogue this if version you had wont to like return it of if course you for have no so clue chill  confusion to
# Epoch 25/200
# 391/391 [==============================] - 1989s 5s/step - loss: 3.9178
# == Generating with temperature 0.2
# This movie was was hilarious just from from the the moment middle things of left the in cinema the in first the place 2 did brothers not and excuse i the believed jokes that were the crap jokes they more were than funny funny one clips joke the at film times hour
# == Generating with temperature 0.5
# This movie film is is great almost the as more if violent it scenes is have pure holes truth the about shadow the and movie murders watch that out film of isnt the amazing point cast of at each all of then the too main many bad of points the if film
# == Generating with temperature 0.7
# This movie is is full a of terminator [UNK] with type a of cop [UNK] the thomas [UNK] martin mother [UNK] of is a moving pattern and of moving course it where has the its film patient is never seen cast [UNK] in [UNK] any comes other when screen his fades wife
# == Generating with temperature 1.0
# This movie movie has made a some bad bad reviews acting come about into as it much features so a called bunch student of detectives [UNK] whos and idea now its that a getting school [UNK] and and the double editing sometimes speaks it so seems badly like made a james longtime
# == Generating with temperature 1.5
# This movie film is is a long poor [UNK] cross a between dog the and [UNK] the i fallen saw asleep was through a it video was and so anything stupid but but i more dont button want more to than know do any you of to those waste predictable at [UNK]
# Epoch 26/200
# 391/391 [==============================] - 1990s 5s/step - loss: 3.9103
# == Generating with temperature 0.2
# This movie guy was was worse known than as the flash stupidest gordon movie picture i of hate this this movie [UNK] the starring story [UNK] linda jones blair she haunting portraying in it a as snake a because reference it for i herself just meet watched her her unfold and with
# == Generating with temperature 0.5
# This movie show revival turns through out out the the control worst program piece ever of all not time a its dumb almost great as i an said [UNK] [UNK] probably movie one for of that [UNK] matter had i it never have had time a to mob sit movie down again
# == Generating with temperature 0.7
# This movie is was great so fun the to music be in set place and but brings if a you lil know pimp things in like all this of structured what life became is back why then must the it music all is the [UNK] same but gained i respect green watching
# == Generating with temperature 1.0
# This movie is makes a me great want but to otherwise understand comment all only the speaking expectations cannon have can you in tell with with an a [UNK] budget austrian unless actors you mixed bronson to must see have this all much swedish better movies than you this know have what
# == Generating with temperature 1.5
# This movie is was the absolutely story awful of so canadian if humour you had just read served its in title the flashbacks story titled do what they would might do be to as cost an to april represent fools a day place cannot to make terribly jokes if unless this they
# Epoch 27/200
# 391/391 [==============================] - 1997s 5s/step - loss: 3.9033
# == Generating with temperature 0.2
# This movie film left changed me with that non point [UNK] time in the the case tradition of of others movies in should which [UNK] the toss [UNK] of [UNK] emotion it and was then what [UNK] the the film rest cant of seem this so film awful is like around a
# == Generating with temperature 0.5
# This movie is is the an kind airport four movie its where detailed the ed last wood film in is its this way is and a it pretty establishes hard the as [UNK] also breaking political up messages its that deep so in many its ways script the is intensity well of
# == Generating with temperature 0.7
# This movie film made fired few by months actors before on producing famous one tv of rod those serling [UNK] wonders but if because not i exactly really enjoyed interested it in a this [UNK] story club the and writer the apparently film tried doesnt in work this as film a and
# == Generating with temperature 1.0
# This movie movie does starts a out little search slow for for the the first other murder half to of keep course the does story acceptable and and the really overall stupid effect storyline of line treatment was seems not very that often of it people this call is a not small
# == Generating with temperature 1.5
# This movie is was very a authentic very look early at on the when french the movies whole second history were was [UNK] also made one in movie more history history about along in the germany [UNK] spain and and had slowly children passed and over moved you with the the words
# Epoch 28/200
# 391/391 [==============================] - 1992s 5s/step - loss: 3.8967
# == Generating with temperature 0.2
# This movie movie shows was the something same i do liked not the russian scenes intellectual in torture russia a and good just one spectacular moral movie i about love [UNK] the [UNK] script war were but graphic overall and i entertaining think it that was a very bit easy better on
# == Generating with temperature 0.5
# This movie is starts a real series fx of called weird [UNK] mysterious and alien in creatures outer as space they survivor stop of from rip [UNK] off ball in and whatever finding money a from king the [UNK] other are buildings cool from [UNK] better [UNK] ways character than has most
# == Generating with temperature 0.7
# This movie is is strictly known dependent as on the your mst3k genre list of as star you wars long will to enjoy say even miniseries for from its writerdirector acting ed here harris the is story an of wrecks four [UNK] cheat the hoping serial to killer bring sean down to
# == Generating with temperature 1.0
# This movie film is was nothing physically special repulsive the it best might way ever to proof make k a example whole of not art sold by for jason example sake [UNK] but in finally both someone cases van this and sucks emily on who the becomes hell is his responsible weak
# == Generating with temperature 1.5
# This movie is has great some acting funny ability moments experts it especially gets the a feeling little of over blatant all ripoff the film featured is cameos good and man also families directed encourage this the while big [UNK] mouth fans will by find national some equals of poor these people
# Epoch 29/200
# 391/391 [==============================] - 1993s 5s/step - loss: 3.8903
# == Generating with temperature 0.2
# This movie movie is is really bad bad especially only when if you not read even reviews the wrote cover the then spoiler nothing says happens the and name sometimes crocodile events gets are [UNK] pleasure and and lots the of presentation this of was the one character that who is is
# == Generating with temperature 0.5
# This movie is was so cute bad that it it was has weird got films to from be the as first bad as as you the saw characters i from saw [UNK] it this get movie especially yet so it so was badly very written [UNK] began has up no to good
# == Generating with temperature 0.7
# This movie movie had was so that gripped it a was [UNK] since a it few had days the before storytelling the to average figure limited as [UNK] an acting actor board introduction is for very someone slow who moving away and from i it would was love open to he blowing
# == Generating with temperature 1.0
# This movie is is great great so playing it it off has my some heart nice wrenching laughing guy very in much a the home movie and it does was not well everything knows i so need much to wrong be with this a movie remake is too not long some with
# == Generating with temperature 1.5
# This movie is is what terrible [UNK] [UNK] my theres teeth a so science bad that that its you crap ive theres got a 2 time for 1 something funny wrong [UNK] i be cant ashamed even i [UNK] forced 3 my the arm tears line through is the beyond mother even
# Epoch 30/200
# 391/391 [==============================] - 1993s 5s/step - loss: 3.8848
# == Generating with temperature 0.2
# This movie is turned terrible the without direction redeeming of the the good whole technical movie aspect lacks of quality the and fx the it sound suffers all from over some a inferior year home upon grainy what poorly is produced [UNK] poorly channel produced the the beatles special the effects film
# == Generating with temperature 0.5
# This movie is is set alright in should placement entertain guns or down blood as of a death genre race training you faster can than see a [UNK] hard or rock a band 6 playing top the star harsh which surly started falls out very in rare [UNK] twenty latin years and
# == Generating with temperature 0.7
# ...
# == Generating with temperature 0.7
# This movie long is before a someone favour wrote and that downside voted is looked so cheesy limited that and you full get five those pm scares animated or monsters not vs the them disney drinks [UNK] subplot swords believability cheesy well cardboard ends box with with a liberties stupidly production stupid
# == Generating with temperature 1.0
# This movie movie is so not innocent very but believable kevin the costner horror played till wonderfully he played brings no the stereotypes usual paired marvelous with dresses william devised james by costner roy [UNK] todd dudikoff michael and ample michael ability ironside to sean portray connery him in in appropriate this
# == Generating with temperature 1.5
# This movie script is means fitting very in [UNK] shame where he it can should come be as thanks [UNK] to some technology muslim with artists the about words how i interesting wrote together this a movie year that theory you peoples just idea cant sloppy express in how any the level
# Epoch 37/200
# 391/391 [==============================] - 2020s 5s/step - loss: 3.8500
# == Generating with temperature 0.2
# This movie film really was includes a characters great which story keeps unlike you most going people with leave is a real true sydney romance with in rupert our everett world theres and a george new lucas friend andy of [UNK] mine people and he by doesnt [UNK] do but anything do
# == Generating with temperature 0.5
# This movie movie was is completely fantastic predictable the and original naked characters at there the so characters we the start fear middle aspect of of the it plot was predictable twisted and to [UNK] the it american had beauty some with of this the movie dialogue is portrays very whos interesting
# == Generating with temperature 0.7
# This movie series was hardly fantastic a of great a saturday great night movie story that a a jewish villain hospital who gets is male one body who who has is almost glamour dying and to i the have movie had with great [UNK] [UNK] include and an [UNK] incredible reporter power
# == Generating with temperature 1.0
# This movie is alone beautiful the enough best comments most on people those imagined for it as as a you highly would suggest think seeing that this you movie might might dont be let famous a but scifi the movie way has moves little very more much than to its tell billing
# == Generating with temperature 1.5
# This movie kind suffers of from been the choreographed kind video of game tomb i [UNK] think there the are animation only cardboard a cutout 3d character that doc is i more guess sound you effects hear in the the sky cover i and would i pull say out more zombies in
# Epoch 38/200
# 391/391 [==============================] - 2009s 5s/step - loss: 3.8457
# == Generating with temperature 0.2
# This movie is doesnt one have of to the like experience i or was am dragged he to crawl see through a the specific movie points and of is his the best beat and were legal it because though the it subject was is beautifully presented constructed it and originally so given
# == Generating with temperature 0.5
# This movie movie was is [UNK] a and scriptwriter another should 1 include thing at 10 the on producers 16 1 grade in 2 playwright rap reginald sing [UNK] why of were course being [UNK] from directed [UNK] for foxy one brown guy night when did he you was get someone limited
# == Generating with temperature 0.7
# This movie movie was succeeds riveting on although its cuts close yes to and the has total but lack it of is dry delta an force egyptian of chick human of hanging most sarandon with [UNK] damn same [UNK] apollo kind still of knowledgeable a ears senior distinct richard che sarandon has
# == Generating with temperature 1.0
# This movie actioner was defy nothing belief with a a little camera more then than shoots as a hes corpse playing hung as out he his dances police styles poor as sound the etc show [UNK] signs into total a silence lower and depths lower than and citizens fewer of group a
# == Generating with temperature 1.5
# This movie film really stands cannot out come because in second terms i it think is i in am my one opinion from of here danny he lee in so hockey convincing not rocky as he the would other have movie to of see recently in on my vhs destination copy without
# Epoch 39/200
# 391/391 [==============================] - 2000s 5s/step - loss: 3.8415
# == Generating with temperature 0.2
# This movie is merely based a on true teachers nature life as after an lucille actor [UNK] is delivers incredibly the bad [UNK] oddly that silliness it i is dont very know bad who as like disney [UNK] but the i four also friends remember worked fred well and i it know
# == Generating with temperature 0.5
# This movie had is a the amsterdam introduction bad after guys which this this would movie really be need thrown help together have ive a seen chat that on way the and guys saying met hey al [UNK] lots also of has times emotions been [UNK] cut documentary of of a several
# == Generating with temperature 0.7
# This movie movie is just the the best damn i accurate have not seen seen it it but might i be say very special good if entertainment you were guys a who good went computer to [UNK] see and it all was puns sad i when sat computer down units to from
# == Generating with temperature 1.0
# This movie isnt sums much up [UNK] the i [UNK] have bored seen halfway it through is the very script ending is is fathers boring and and a terrible bit 2nd too most standards of sometimes them there especially are are not some one good of thing them and [UNK] the gets
# == Generating with temperature 1.5
# This movie movie is was a most wonderful entertained movie i had saw ever it but was could very [UNK] well or directed maybe certainly the they best are cast telling but this the story songs is will good have it great to music be the a movie classic it will is
# Epoch 40/200
# 391/391 [==============================] - 2004s 5s/step - loss: 3.8373
# == Generating with temperature 0.2
# This movie is was perfect surprised and by i apparent can writing only the hold first of impact all newcomer the con cast was was fantastic excellent what one an could ok wonder the how whole people psychopath liked thought them he i said wish it they would would be make a
# == Generating with temperature 0.5
# This movie film is examines a the family difficulties of of growing the up parents we of all our five children kids have camping worked into lizards my with educational friends movies you theyre were just highly going surprised to i find went these out waterfront made we me discover sad some
# == Generating with temperature 0.7
# This movie sequel is is nothing a like match double to team the up [UNK] this old movie movies is style funny for then instance they in are a being joke riding by kids a end car i biting suggest the you quotes get on 4 the times makeup and is the
# == Generating with temperature 1.0
# This movie was was terrible prepared i to found give out it the for shelf about there 20 for minutes ten id pounds placed though rational worse plot seat driven scenery boring and made a me different sort kind of of movie way a before simple it piercing brought scare me me
# == Generating with temperature 1.5
# This movie is features utterly three unbelievable and character very actors very eric badly stoltz script first is known quite for sensibility her possibilities cousin and far [UNK] from to this absurdity because having of been a captured [UNK] and during refused a to hollywood [UNK] tank that chase it was seems
# Epoch 41/200
# 391/391 [==============================] - 2123s 5s/step - loss: 3.8331
# == Generating with temperature 0.2
# This movie is is absolute simply every magic piece of has movies [UNK] going the for plot it and cant the believe makers the of story this the is acting pure for genius the those director who off didnt the tell silence they when were they being were transported thinking to they
# == Generating with temperature 0.5
# This movie movie starts does with [UNK] terrific [UNK] promise of of a a [UNK] young rock screenwriter dancer by rusty and parker her posey car the coach bad professional goes [UNK] [UNK] mayhem [UNK] with humour richards a elevates mentor [UNK] after through passengers a waiting [UNK] [UNK] puts long her
# == Generating with temperature 0.7
# This movie movie had is some the movies cast set and in is this superb seems example more starts than off the half moses [UNK] acting directed but and at then i there was is very a good slow watch paced only movie to but give after it those just people happened
# == Generating with temperature 1.0
# This movie goes was most pretty bad predictable sometimes movie and while had it a just nice wasnt theme like horrible sophisticated scenes guy shot says it something was like old a school [UNK] game it the was main la theme because jesus it did won not so play good by parts
# == Generating with temperature 1.5
# This movie film got is so [UNK] stupid i even would expected [UNK] one friend to i get thought it and style the that story is was much pathetic better showing i a laughed dark at wolf the had film so been [UNK] also done very i good have the the good
# Epoch 42/200
# 391/391 [==============================] - 2176s 6s/step - loss: 3.8291
# == Generating with temperature 0.2
# This movie is shows terrible what true a school mix is i not never submit felt that comics possible nor an that artistic aside medium the since story his was movie at making different jokes loose but about they homosexuality parodies your of basic star instinct [UNK] or characters other indeed than
# == Generating with temperature 0.5
# This movie is was amazingly billed bad as as an a [UNK] los and angeles for i worse had than to audiences try alike to there come is rachael a terry cast fan in interaction this with movie dung including i jason attended [UNK] a a [UNK] sunny surprise middle at eastern
# == Generating with temperature 0.7
# This movie meditation really as gets follows right a through story the of focus an yes officer raise woman is [UNK] torn more between about an and northern elegant ghetto and but emotionally it steaming is the unable only to academic feel masks the and three the of killings them its all
# == Generating with temperature 1.0
# This movie movie is is not pure exciting trash watching and to the stay way true off to this 1993 mortal film kombat luc despite leftwing an bulk american of views thinking shares about zombies [UNK] and also shots victory of the the nathan classic drowns wanna is kennedy neal out soso
# == Generating with temperature 1.5
# This movie film is is a a ripoff sugar of popcorn a brilliance lot that of cant crap be but a stereotypical movie unimaginative starring teen sgt porn inventor movie creates that a i serious dont medical meant care that bears is its described a on joke the see morals due of
# Epoch 43/200
# 391/391 [==============================] - 2374s 6s/step - loss: 3.8252
# == Generating with temperature 0.2
# This movie series dont was go the forward same good concept actors that unfortunately look decided right that the story script would seems be to slightly focused be in because actual the story budget was just pretty a interesting waste story of idea time moving and enough some it teen wouldve comedy
# == Generating with temperature 0.5
# This movie popular is in a history [UNK] class [UNK] and about its the a sort unique of tale [UNK] in and the of 50s the the period way though the this subject movie was works [UNK] in and a while contemporary there references are to a the time [UNK] you [UNK]
# == Generating with temperature 0.7
# This movie movie starts [UNK] out [UNK] with at an the open big terror city and town [UNK] where by a the woman world [UNK] is is a the writer monster headed expert by monster voiced invincible by to [UNK] the j four [UNK] a [UNK] later who hates authenticity him for
# == Generating with temperature 1.0
# This movie is was just [UNK] so bad bad it i is almost a impressions power 3 at out least right one after word 10 go minutes because or the so whole bad movie it was really a annoying little mommy child oh [UNK] yes she many finds girls herself all as
# == Generating with temperature 1.5
# This movie film was was designed horrible to [UNK] take the manhattan seriously film it michael was succeeds dark in and an on atmosphere all and [UNK] film around audio the productions shown of throughout it but was if worse you its put terribly from in the terms main of part its
# Epoch 44/200
# 248/391 [==================>...........] - ETA: 14:25 - loss: 3.8244
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\CD86~1\AppData\Local\Temp/ipykernel_11720/1942794232.py in <module>
# ----> 1 model.fit(lm_dataset, epochs=200, callbacks=[text_gen_callback])
#
# C:\python\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# C:\python\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# C:\python\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# C:\python\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# C:\python\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# C:\python\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# C:\python\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
